# %%
# Install BeautifulSoup and Requests if you haven't already
# !pip install beautifulsoup4 requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
# Define the URL and download the page
url = "https://www.courtlistener.com/docket/69609277/penguin-random-house-llc-v-labrador/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
html = response.text

# %%
# Parse the HTML using BeautifulSoup
soup = BeautifulSoup(html, "html.parser")
print(soup.title.string)
print(url)
# Out:
# Penguin Random House LLC v. Labrador, 1:25-cv-00061 – CourtListener.com
# https://www.courtlistener.com/docket/69609277/penguin-random-house-llc-v-labrador/

# %%
for div in soup.find_all("div", id=True):
    print(div.get("id"))
# Out:
# modal-logged-out
# modal-no-more-alerts
# tutorialModal
# react-root
# main-query-box
# search-container
# sort-buttons
# docket-entry-table
# entry-1
# entry-2
# entry-3
# entry-4
# entry-5
# entry-6
# entry-7
# entry-8
# entry-9
# entry-10
# entry-11
# entry-12
# entry-13
# entry-14
# entry-15
# minute-entry-415837636
# entry-16
# entry-17
# entry-18
# entry-19
# entry-20
# entry-21
# entry-22
# entry-23
# entry-24
# entry-25
# entry-26
# entry-27
# entry-28
# entry-29
# entry-30
# entry-31
# entry-32
# entry-33
# entry-34
# entry-35
# entry-36
# entry-37
# entry-38
# entry-39
# entry-40
# entry-41
# entry-42
# minute-entry-419566110
# minute-entry-419566111
# entry-43
# entry-44
# minute-entry-419566114
# entry-46
# donate-image
# by-line
# social-container
# modal-buy-pacer

# %%
# Find all divs with an id starting with 'entry-'
entry_ids = [div.get("id") for div in soup.find_all("div", id=True) if div.get("id").startswith("entry-")]

# Extract the numbers from the entry-ids
entry_numbers = [int(entry_id.split('-')[1]) for entry_id in entry_ids]

# Find the highest entry number
max_entry = max(entry_numbers)

# Print the first entry (entry-1)
first_entry = soup.find("div", id="entry-1")
if first_entry:
    # Extract the <a> tags within the div and print the text and link for each
    for a_tag in first_entry.find_all("a", href=True):
        link_text = a_tag.text.strip()  # Get the text of the hyperlink
        link_url = a_tag.get("href")  # Get the URL of the hyperlink
        print(f"{link_text} > {link_url}")

# Print the last entry (entry-max_entry)
last_entry = soup.find("div", id=f"entry-{max_entry}")
if last_entry:
    # Extract the <a> tags within the div and print the text and link for each
    for a_tag in last_entry.find_all("a", href=True):
        link_text = a_tag.text.strip()  # Get the text of the hyperlink
        link_url = a_tag.get("href")  # Get the URL of the hyperlink
        print(f"{link_text} > {link_url}")
# Out:
# Main Doc­ument > /docket/69609277/1/penguin-random-house-llc-v-labrador/
# Download PDF > https://storage.courtlistener.com/recap/gov.uscourts.idd.56244/gov.uscourts.idd.56244.1.0_1.pdf
# From
#                           CourtListener > https://storage.courtlistener.com/recap/gov.uscourts.idd.56244/gov.uscourts.idd.56244.1.0_1.pdf
# From
#                             Internet Archive > https://archive.org/download/gov.uscourts.idd.56244/gov.uscourts.idd.56244.1.0.pdf
# Buy on PACER ($3.00) > https://ecf.idd.uscourts.gov/doc1/06303011634?caseid=56244
#  > https://storage.courtlistener.com/recap/gov.uscourts.idd.56244/gov.uscourts.idd.56244.1.0_1.pdf
#  > #entry-1
# Buy on PACER > https://ecf.idd.uscourts.gov/doc1/06303031647?caseid=56244
#  > https://ecf.idd.uscourts.gov/doc1/06303031647?caseid=56244
#  > #entry-46
